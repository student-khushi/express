# %% [markdown]
# <a href="https://colab.research.google.com/github/student-khushi/express/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
# x-axis values
x=[2,4,5,7,9]
#Y-axis values

y = [3,5,8,9,12]

#Function to plot

plt.plot(x, y,linewidth = '10')

#function to show the plot

plt.show()

# %%
from matplotlib import pyplot as plt

x = [2,4,5,7,9]

y = [3,5,8,9,12]

plt.plot(x, y)

plt.grid()
plt.plot(x, y,linewidth = '10')


plt.show()

# %%
import matplotlib.pyplot as plt

import numpy as np

data= np.random.randn(1000)

plt.hist(data, bins=20, edgecolor='black')
# Out:
# (array([  1.,   0.,   4.,  12.,  24.,  50.,  74., 120., 149., 151., 135.,
#         110.,  70.,  49.,  24.,  17.,   7.,   2.,   0.,   1.]),
#  array([-3.77887959, -3.38676902, -2.99465845, -2.60254788, -2.21043731,
#         -1.81832674, -1.42621618, -1.03410561, -0.64199504, -0.24988447,
#          0.1422261 ,  0.53433667,  0.92644724,  1.31855781,  1.71066837,
#          2.10277894,  2.49488951,  2.88700008,  3.27911065,  3.67122122,
#          4.06333179]),
#  <BarContainer object of 20 artists>)

# %%
import numpy as np
x = np.array(["А", "B", "C", "D"])
y = np.array( [3, 8, 1, 10])
plt.bar(x,y,color="blue")
plt.show()

# %%
import numpy as np
x = np.array(["А", "B", "C", "D"])
y = np.array( [3, 8, 1, 10])
plt.barh(x,y,color="yellow")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#day one, the age and speed of 13 cars:

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color='red')


#day two, the age and speed of 15 cars:

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])

y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])

plt.scatter(x, y, marker='s')

plt.title('Scatter Example', loc = 'left')

plt.show()
